# %%
import streamlit as st
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
st.title("Предсказание оттока клиентов (Churn) — ML Модель")

# --- File upload ---
uploaded = st.file_uploader("Загрузите CSV-файл с данными", type="csv")

if uploaded is None:
    st.info("Пожалуйста, загрузите файл, чтобы продолжить")
    st.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 st.title("Предсказание оттока клиентов (Churn) — ML Модель")
#       3 # --- File upload ---
#       4 uploaded = st.file_uploader("Загрузите CSV-файл с данными", type="csv")
#
# NameError: name 'st' is not defined

# %%
# --- Load data ---
df = pd.read_csv(uploaded)
st.subheader("Первые строки данных:")
st.write(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # --- Load data ---
# ----> 2 df = pd.read_csv(uploaded)
#       3 st.subheader("Первые строки данных:")
#       4 st.write(df.head())
#
# NameError: name 'pd' is not defined

# %%
# --- Basic info ---
st.subheader("Информация о данных")
st.write("Количество пропусков по столбцам:")
st.write(df.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # --- Basic info ---
# ----> 2 st.subheader("Информация о данных")
#       3 st.write("Количество пропусков по столбцам:")
#       4 st.write(df.isna().sum())
#
# NameError: name 'st' is not defined

# %%
# --- Preprocessing ---
if "customerid" in df.columns:
    df.drop("customerid", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # --- Preprocessing ---
# ----> 2 if "customerid" in df.columns:
#       3     df.drop("customerid", axis=1, inplace=True)
#
# NameError: name 'df' is not defined

# %%
# Encoding categorical columns
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = LabelEncoder().fit_transform(df[col])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Encoding categorical columns
# ----> 2 for col in df.columns:
#       3     if df[col].dtype == 'object':
#       4         df[col] = LabelEncoder().fit_transform(df[col])
#
# NameError: name 'df' is not defined

# %%
# --- Train model button ---
if st.button("Обучить модель"):
    if "churn" not in df.columns:
        st.error("Ошибка: В данных нет столбца 'churn'")
        st.stop()

    X = df.drop("churn", axis=1)
    y = df["churn"]

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.25, random_state=42
    )

    model = RandomForestClassifier(n_estimators=300, random_state=42)
    model.fit(X_train, y_train)

    preds = model.predict(X_test)
    probs = model.predict_proba(X_test)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # --- Train model button ---
# ----> 2 if st.button("Обучить модель"):
#       3     if "churn" not in df.columns:
#       4         st.error("Ошибка: В данных нет столбца 'churn'")
#
# NameError: name 'st' is not defined

# %%
st.success("Модель обучена!")

    st.subheader("Метрики модели")
    st.write("Accuracy:", accuracy_score(y_test, preds))
    st.write("ROC-AUC:", roc_auc_score(y_test, probs))

    st.text("Classification Report:")
    st.text(classification_report(y_test, preds))

    st.subheader("Confusion Matrix")
    st.write(confusion_matrix(y_test, preds))
# Out:
#   Cell In[8], line 3
#     st.subheader("Метрики модели")
#     ^
# IndentationError: unexpected indent
